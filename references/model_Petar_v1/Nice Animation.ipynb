# %%
import plotly

# %%
import plotly.express as px

# %%
gapminder_df = px.data.gapminder()

# %%
gapminder_df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
serbia_gdf = gapminder_df[gapminder_df['country'] == 'Serbia']

# %%
serbia_gdf
# Out:
#      country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 1332  Serbia    Europe  1952   57.996   6860147   3581.459448       SRB
# 1333  Serbia    Europe  1957   61.685   7271135   4981.090891       SRB
# 1334  Serbia    Europe  1962   64.531   7616060   6289.629157       SRB
# 1335  Serbia    Europe  1967   66.914   7971222   7991.707066       SRB
# 1336  Serbia    Europe  1972   68.700   8313288  10522.067490       SRB
# 1337  Serbia    Europe  1977   70.300   8686367  12980.669560       SRB
# 1338  Serbia    Europe  1982   70.162   9032824  15181.092700       SRB
# 1339  Serbia    Europe  1987   71.218   9230783  15870.878510       SRB
# 1340  Serbia    Europe  1992   71.659   9826397   9325.068238       SRB
# 1341  Serbia    Europe  1997   72.232  10336594   7914.320304       SRB
# 1342  Serbia    Europe  2002   73.213  10111559   7236.075251       SRB
# 1343  Serbia    Europe  2007   74.002  10150265   9786.534714       SRB
#
#       iso_num
# 1332      688
# ...

# %%
fg = px.scatter(data_frame=serbia_gdf, x='gdpPercap', y='lifeExp',size='pop', color='continent',title="Life Span and Wealth 1952 - 2007", labels={'gdpPercap': 'Wealth', 'lifeExp' : 'Life Span'}, log_x=True, range_y=[25,95], hover_name='country',animation_frame='year',height=600,size_max=100)

# %%
fg.show()

# %%
fg = px.scatter(data_frame=gapminder_df, x='gdpPercap', y='lifeExp',size='pop', color='continent',title="Life Span and Wealth 1952 - 2007", labels={'gdpPercap': 'Wealth', 'lifeExp' : 'Life Span'}, log_x=True, range_y=[25,95], hover_name='country',animation_frame='year',height=600,size_max=100)

# %%
fg.show()

# %%
import imageio

# %%
import random
import plotly.graph_objects as go
import pandas as pd
import gif
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import io 
import imageio

# %%
fg.write_html('life_span_and_wealth.html')

# %%
frames = []
for i, frame in enumerate(fg.frames):
    frame_name = f"frame_{i:03}.png"
    fg.to_image(format="png", width=600, height=400, scale=2).save(frame_name)
    frames.append(imageio.imread(frame_name))

# %%
#Create the GIF animation using the imageio module
imageio.mimsave('scatter_plot_animation.gif', frames, duration=0.2)
